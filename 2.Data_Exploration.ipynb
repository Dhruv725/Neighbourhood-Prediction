# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading CSV File which was saved earlier and gathered data using API calls.
df=pd.read_csv("datawithPrices.csv")
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    Unnamed: 0                         Place Name              Category  \
# 0           2  Elgin & Winter Garden Theatre Ctr           Music Venue
# 1          11                 Carville Mill Park                  Park
# 2          23                 Hina's Beauty Care            Hair Salon
# 3          34                   Richmond Station   American Restaurant
# 4          44                   Cactus Club Cafe   American Restaurant
# 5          46                    Markham Corners         Shopping Mall
# 6          54         Cherry beach sports fields          Soccer Field
# 7          63                        Metro Grill  Fast Food Restaurant
# 8          82                               Toca                   Bar
# 9          87                 Akira Back Toronto   Japanese Restaurant
#
#   PostalCode           Borough  \
# 0        M5B  Downtown Toronto
# 1        M5B  Downtown Toronto
# 2        M5B  Downtown Toronto
# 3        M5H  Downtown Toronto
# ...

# %%
df.shape
# Out:
# (1242, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1242 entries, 0 to 1241
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1242 non-null   int64
#  1   Place Name    1242 non-null   object
#  2   Category      1242 non-null   object
#  3   PostalCode    1242 non-null   object
#  4   Borough       1242 non-null   object
#  5   Neighborhood  1242 non-null   object
#  6   Latitude      1242 non-null   float64
#  7   Longitude     1242 non-null   float64
#  8   HousingPrice  1242 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 87.5+ KB

# %% [markdown]
# Most common place type in the data is Restaurant.

# %%
df.Category.value_counts()
# Out:
# Restaurant              53
# Park                    52
# Café                    50
# Bakery                  44
# Diner                   39
#                         ..
# Laser Tag Center         1
# Aquarium                 1
# Pest Control Service     1
# Karaoke Bar              1
# Dumpling Restaurant      1
# Name: Category, Length: 274, dtype: int64

# %% [markdown]
# No null values in the dataset.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Place Name      0
# Category        0
# PostalCode      0
# Borough         0
# Neighborhood    0
# Latitude        0
# Longitude       0
# HousingPrice    0
# dtype: int64

# %%
#Unique Values
unique_values = pd.DataFrame(
 columns=['Unique Values']
)
for row in list(df.columns.values):
 unique_values.loc[row] = [df[row].nunique()]
unique_values
# Out:
#              Unique Values
# Unnamed: 0            1242
# Place Name            1242
# Category               274
# PostalCode             101
# Borough                 13
# Neighborhood           101
# Latitude               101
# Longitude               73
# HousingPrice            13

# %% [markdown]
# No missing data in the dataset.

# %%
missing_data = pd.DataFrame(
 df.isnull().sum(),
 columns=['Missing Values']
)
missing_data
# Out:
#               Missing Values
# Unnamed: 0                 0
# Place Name                 0
# Category                   0
# PostalCode                 0
# Borough                    0
# Neighborhood               0
# Latitude                   0
# Longitude                  0
# HousingPrice               0

# %%
data_types = pd.DataFrame(
 df.dtypes,
 columns=['Data Type']
)
data_types
# Out:
#              Data Type
# Unnamed: 0       int64
# Place Name      object
# Category        object
# PostalCode      object
# Borough         object
# Neighborhood    object
# Latitude       float64
# Longitude      float64
# HousingPrice     int64

# %% [markdown]
# <b> Data Quality Report </b>

# %%
dq_report = data_types.join(missing_data).join(unique_values)
dq_report
# Out:
#              Data Type  Missing Values Unique Values
# Unnamed: 0       int64               0          1242
# Place Name      object               0          1242
# Category        object               0           274
# PostalCode      object               0           101
# Borough         object               0            13
# Neighborhood    object               0           101
# Latitude       float64               0           101
# Longitude      float64               0            73
# HousingPrice     int64               0            13

# %% [markdown]
# <b> Analysis of the data -</b>
# Overall data quality is good. It has more than 1200 columns and no missing or null values in the dataset. Target column HousingPrice is there to predict its values later on using machine learning models.
